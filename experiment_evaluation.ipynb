# %%
import exp_utils

#Folder containing all experiment files
fileFolder = './src/log/HFODomain/'
#fileFolder = './src/log/HFODomain_backup0-2/'
#Experiment 1 - Simultaneously Learning agents


source1 = fileFolder + 'SARSA-NoneCurriculum'
source2 = fileFolder + 'PITAMSARSA-PrunedGeneratedCurriculum'#'PITAMSARSA-GeneratedSourceOOCurriculum'
source3 = fileFolder + 'VFReuseSARSA-SvetlikCurriculum'
source4 = fileFolder + 'PITAMSARSA-PrunedCurriculum'
source5 = fileFolder + 'Dummy-NoneCurriculum'
source6 = fileFolder + 'PITAMSARSA-GeneratedSourceOOCurriculum_bkp'



name1 = 'No Curriculum'
name2 = 'OO-Generated'
name3 = 'Svetlik'
name4 = 'OO-Given'
name5 = 'Random'
name6 = 'Random'
#name6 = 'Scratch'

startingCumulative = 10000
confidence = 0.9

#Prepare intermediary files with experiment's summary.
exp_utils.collect_experiment_data(source1, runs = 50)
exp_utils.summarize_experiment_data(source1,confidence=confidence)
exp_utils.cumulative_experiment_data(source1,startingFrom=startingCumulative)
exp_utils.collect_experiment_data(source2, runs = 50)
exp_utils.summarize_experiment_data(source2,confidence=confidence)
exp_utils.cumulative_experiment_data(source2,startingFrom=startingCumulative)
exp_utils.collect_experiment_data(source3, runs =50)
exp_utils.summarize_experiment_data(source3,confidence=confidence)
exp_utils.cumulative_experiment_data(source3,startingFrom=startingCumulative)
exp_utils.collect_experiment_data(source4, runs =50)
exp_utils.summarize_experiment_data(source4,confidence=confidence)
exp_utils.cumulative_experiment_data(source4,startingFrom=startingCumulative)
exp_utils.collect_experiment_data(source5, runs =50)
exp_utils.summarize_experiment_data(source5,confidence=confidence)
exp_utils.cumulative_experiment_data(source5,startingFrom=startingCumulative)
#exp_utils.collect_experiment_data(source6, runs =50)
#exp_utils.summarize_experiment_data(source6,confidence=confidence)
#exp_utils.cumulative_experiment_data(source6,startingFrom=startingCumulative)


#Intervals for zoomed averages
#xMinPerc = 4500
#xMaxPerc = 5000
#yMinPerc = 64
#yMaxPerc = 75

#Intervals for Time for Goal graphs
###xMinStep = 3000
#xMaxStep = 5000
#yMinStep = 95
#yMaxStep = 110

#xMinStep2 = 0
##xMaxStep2 = 1000
#yMinStep2 = 30
#yMaxStep2 = 110


printCI = True


exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,#source5=source5,name5=name5,#source6=source6,name6=name6,
                     ci=printCI,what='__SUMMARY_goal',bigFont = True,nCol=2,markEvery=3)
exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,#source5=source5,name5=name5,#source6=source6,name6=name6,
                     ci=printCI,what='__SHIFTED_goal',bigFont = True,nCol=2)
exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,#source5=source5,name5=name5,#source6=source6,name6=name6,
                     ci=False,what='__CUMULATIVE_goal',bigFont = True,nCol=2,markEvery=10)
exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,#source5=source5,name5=name5,#source6=source6,name6=name6,
                     ci=False,what='__CUM_SHIFTED_goal',bigFont = True,nCol=2,markEvery=10)
exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,#source5=source5,name5=name5,#source6=source6,name6=name6,
                     ci=False,what='__CUMULATIVE_goal',xMin=80000,xMax=100000,yMin=550,yMax=850,bigFont = True,nCol=2,markEvery=5)
exp_utils.draw_grap4h(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,#source5=source5,name5=name5,#source6=source6,name6=name6,
                     ci=printCI,what='__SUMMARY_rewards')
exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,#source5=source5,name5=name5,#source6=source6,name6=name6,
                     ci=printCI,what='__SUMMARY_steps')#,xMax = 10000, xMin=0)
# Out:
# /home/leno/gitProjects/Curriculum_HFO/exp_utils.py:39: UserWarning: loadtxt: Empty input file: "<_io.BufferedReader name='./src/log/HFODomain/SARSA-NoneCurriculum/_0_30_AGENT_1_RESULTS_eval'>"
#   _etime, _estep, _ereward, _egoalP = np.loadtxt(open(evalFile, "rb"), skiprows=1, delimiter=",", unpack=True)
# Could use 49 runs from expected 50
# Could use 49 runs from expected 50
# Could use 50 runs from expected 50
# Could use 50 runs from expected 50
# /home/leno/gitProjects/Curriculum_HFO/exp_utils.py:39: UserWarning: loadtxt: Empty input file: "<_io.BufferedReader name='./src/log/HFODomain/Dummy-NoneCurriculum/_0_1_AGENT_1_RESULTS_eval'>"
#   _etime, _estep, _ereward, _egoalP = np.loadtxt(open(evalFile, "rb"), skiprows=1, delimiter=",", unpack=True)
# /home/leno/gitProjects/Curriculum_HFO/exp_utils.py:39: UserWarning: loadtxt: Empty input file: "<_io.BufferedReader name='./src/log/HFODomain/Dummy-NoneCurriculum/_0_8_AGENT_1_RESULTS_eval'>"
#   _etime, _estep, _ereward, _egoalP = np.loadtxt(open(evalFile, "rb"), skiprows=1, delimiter=",", unpack=True)
# /home/leno/gitProjects/Curriculum_HFO/exp_utils.py:310: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   plt.gca().set_axis_bgcolor('white')
# Could use 6 runs from expected 50
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-267cda56b51b> in <module>()
#      79 exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,#source5=source5,name5=name5,#source6=source6,name6=name6,
#      80                      ci=False,what='__CUMULATIVE_goal',xMin=80000,xMax=100000,yMin=550,yMax=850,bigFont = True,nCol=2,markEvery=5)
# ---> 81 exp_utils.draw_grap4h(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,#source5=source5,name5=name5,#source6=source6,name6=name6,
#      82                      ci=printCI,what='__SUMMARY_rewards')
#      83 exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,#source5=source5,name5=name5,#source6=source6,name6=name6,
#
# AttributeError: module 'exp_utils' has no attribute 'draw_grap4h'
